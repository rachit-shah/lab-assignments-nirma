# %%
# %matplotlib inline
import matplotlib
import pandas as pd
import numpy as np


df = pd.read_csv("dataset.csv", encoding = "ISO-8859-1")

# %%
temp = df['Lyrics']
temp2 = df['Genre']
df = pd.DataFrame(df.SongInfo.str.split(' - ',1).tolist(),columns=['Artist','SongTitle'])
df['SongTitle'] = df.SongTitle.str.replace(" LYRICS","")
df = df.join(temp)
df = df.join(temp2)
df['Genre'] = df.Genre.str.replace("Country Music","Country")
df['Genre'] = df.Genre.str.replace("Hip Hop/Rap","Rap")

# %%
df
# Out:
#                              Artist  \
# 0                    CASTING CROWNS
# 1                    GLORY REVEALED
# 2                    CAEDMON'S CALL
# 3                           MERCYME
# 4                       AARON SHUST
# 5                  MICHAEL W. SMITH
# 6                      CHRIS TOMLIN
# 7                       LAURA STORY
# 8                            TREE63
# 9                      CHRIS TOMLIN
# 10                   CASTING CROWNS
# 11                       SWITCHFOOT
# 12                          MERCYME
# 13                     CHRIS TOMLIN
# 14                          MERCYME
# 15                     CHRIS TOMLIN
# 16                     CHRIS TOMLIN
# 17                     CHRIS TOMLIN
# 18                        THIRD DAY
# 19          PHILLIPS CRAIG AND DEAN
# 20                      JOHN WALLER
# 21                     RICH MULLINS
# 22                 NICOLE C. MULLEN
# 23                          TOBYMAC
# 24                            SELAH
# 25                       SWITCHFOOT
# 26                 MICHAEL W. SMITH
# 27                   CASTING CROWNS
# 28                      THE KATINAS
# 29               TENTH AVENUE NORTH
# ..                              ...
# 528                      SAM & DAVE
# 529                 THE MARVELETTES
# 530                   CONLEY ARTHUR
# 531                 MINNIE RIPERTON
# 532             THE SUGAR HILL GANG
# 533                   GENE CHANDLER
# 534                      ETTA JAMES
# 535   MARTHA REEVES & THE VANDELLAS
# 536                   WONDER STEVIE
# 537   JUNIOR WALKER & THE ALL STARS
# 538                    OTIS REDDING
# 539                      KING FLOYD
# 540                       FOUR TOPS
# 541        ARCHIE BELL & THE DRELLS
# 542                    BILL WITHERS
# 543                             WAR
# 544                 THE TEMPTATIONS
# 545                      THE O'JAYS
# 546                    THE DRIFTERS
# 547                  WILSON PICKETT
# 548  SMOKEY ROBINSON & THE MIRACLES
# 549                     BARRY WHITE
# 550           SCREAMIN' JAY HAWKINS
# 551                 CLARENCE CARTER
# 552             EARTH WIND AND FIRE
# 553                     JAMES BROWN
# 554                    BROOK BENTON
# 555                        AL GREEN
# 556                    CHUCK WILLIS
# 557          SLY & THE FAMILY STONE
#
#                                              SongTitle  \
# 0                                             WHO AM I
# 1                                        BY HIS WOUNDS
# 2                                       GOD OF WONDERS
# 3                                   I CAN ONLY IMAGINE
# 4                                     MY SAVIOR MY GOD
# 5                                              BREATHE
# 6                                 HOW GREAT IS OUR GOD
# 7                                       MIGHTY TO SAVE
# 8                                 BLESSED BE YOUR NAME
# 9                                     HOLY IS THE LORD
# 10                                        EAST TO WEST
# 11                                              ALWAYS
# 12                                      BRING THE RAIN
# 13                                       INDESCRIBABLE
# 14                                   WORD OF GOD SPEAK
# 15                                       JESUS MESSIAH
# 16                                         I WILL RISE
# 28    Just a little while longer I wanna pray Cant ...  Christian
# 29    How long must I pray, must I pray to You How ...  Christian
# ..                                                 ...        ...
# 528   Coming to you on a dusty road Good loving, I ...        R&B
# 529   Wait! Oh yes, wait just a minute Mr. Postman ...        R&B
# 530   Do you like good music  That sweet soul music...        R&B
# 531   I believe any dream that I want to That aint ...        R&B
# 532   I said-a hip, hop, the hippie, the hippie To ...        R&B
# 533   Its the Duke of Earlâ¦ (Celebrating time) Ah...        R&B
# 534   You thought you had found a good girl One to ...        R&B
# 535   Jimmy Mack, Jimmy Oh, Jimmy Mack When are you...        R&B
# 536   Wonder Stevie Miscellaneous Superstition Supe...        R&B
# 537   I said, Ã¢â¬Â½Shotgun shoot em for he runs n...        R&B
# 538   Fa-Fa-Fa-Fa-Fa-Fa-Fa-Fa-Fa  Fa-Fa-Fa-Fa-Fa-Fa...        R&B
# 539   Uhh, aww, sookie, sookie now Hey, oww, uhh, c...        R&B
# 540   Standing in the shadows of love Im getting re...        R&B
# 541   Hi everybody  Im Archie Bell of the Drells  F...        R&B
# 542   Sometimes in our lives We all have pain We al...        R&B
# 543   INSTRUMENTAL All my friends know the low ride...        R&B
# 544   Hold it, everybody Hold it, hold it, listen  ...        R&B
# 545   The Ojays Miscellaneous Love Train LOVE TRAIN...        R&B
# 546   Love me, love me Love me, love me-lo Love me,...        R&B
# 547   Mustang Sally Guess you better slow your Must...        R&B
# 548   I dont like you, but I love you Seems that Im...        R&B
# 549   You got me doin it, you got me doin it You go...        R&B
# 550   I put a spell on you Because youre mine Stop ...        R&B
# 551   (Spoken:) I was born and raised down in Alaba...        R&B
# 552   Earth Wind And Fire All N All Serpentine Fire...        R&B
# 553   Ha I dont care ha, about your past I just wan...        R&B
# 554   Hoverin by my suitcase  Tryin to find a warm ...        R&B
# 555   I dont know why I love you like I do  After a...        R&B
# 556   C. C. Rider Elvis Presley  Well now see., C. ...        R&B
# 557   Cynthia get up and dance to the music!  Get o...        R&B
#
# [558 rows x 4 columns]

# %%
df= df.drop_duplicates(subset="SongTitle")
df['Genre'].value_counts()
# Out:
# Pop          96
# Christian    94
# Rock         92
# Rap          91
# Country      87
# R&B          86
# Name: Genre, dtype: int64

# %%
wordcounts = df.Lyrics.str.split().apply(len)
df['WordCounts'] = wordcounts
df
# Out:
# c:\users\hp\anaconda3\envs\tensor\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                              Artist  \
# 0                    CASTING CROWNS
# 1                    GLORY REVEALED
# 2                    CAEDMON'S CALL
# 3                           MERCYME
# 4                       AARON SHUST
# 5                  MICHAEL W. SMITH
# 6                      CHRIS TOMLIN
# 7                       LAURA STORY
# 8                            TREE63
# 9                      CHRIS TOMLIN
# 10                   CASTING CROWNS
# 11                       SWITCHFOOT
# 12                          MERCYME
# 13                     CHRIS TOMLIN
# 14                          MERCYME
# 15                     CHRIS TOMLIN
# 16                     CHRIS TOMLIN
# 17                     CHRIS TOMLIN
# 18                        THIRD DAY
# 19          PHILLIPS CRAIG AND DEAN
# 20                      JOHN WALLER
# 21                     RICH MULLINS
# 22                 NICOLE C. MULLEN
# 23                          TOBYMAC
# 24                            SELAH
# 25                       SWITCHFOOT
# 26                 MICHAEL W. SMITH
# 27                   CASTING CROWNS
# 28                      THE KATINAS
# 29               TENTH AVENUE NORTH
# ..                              ...
# 527              THE ISLEY BROTHERS
# 528                      SAM & DAVE
# 529                 THE MARVELETTES
# 530                   CONLEY ARTHUR
# 531                 MINNIE RIPERTON
# 532             THE SUGAR HILL GANG
# 533                   GENE CHANDLER
# 534                      ETTA JAMES
# 535   MARTHA REEVES & THE VANDELLAS
# 537   JUNIOR WALKER & THE ALL STARS
# 538                    OTIS REDDING
# 539                      KING FLOYD
# 540                       FOUR TOPS
# 541        ARCHIE BELL & THE DRELLS
# 542                    BILL WITHERS
# 543                             WAR
# 544                 THE TEMPTATIONS
# 545                      THE O'JAYS
# 546                    THE DRIFTERS
# 547                  WILSON PICKETT
# 548  SMOKEY ROBINSON & THE MIRACLES
# 549                     BARRY WHITE
# 550           SCREAMIN' JAY HAWKINS
# 551                 CLARENCE CARTER
# 552             EARTH WIND AND FIRE
# 553                     JAMES BROWN
# 554                    BROOK BENTON
# 555                        AL GREEN
# 556                    CHUCK WILLIS
# 557          SLY & THE FAMILY STONE
#
#                                              SongTitle  \
# 0                                             WHO AM I
# 1                                        BY HIS WOUNDS
# 2                                       GOD OF WONDERS
# 3                                   I CAN ONLY IMAGINE
# 4                                     MY SAVIOR MY GOD
# 5                                              BREATHE
# 6                                 HOW GREAT IS OUR GOD
# 7                                       MIGHTY TO SAVE
# 8                                 BLESSED BE YOUR NAME
# 9                                     HOLY IS THE LORD
# 10                                        EAST TO WEST
# 11                                              ALWAYS
# 12                                      BRING THE RAIN
# 13                                       INDESCRIBABLE
# 14                                   WORD OF GOD SPEAK
# 15                                       JESUS MESSIAH
# 16                                         I WILL RISE
# 17                  AMAZING GRACE (MY CHAINS ARE GONE)
# 18                                    CRY OUT TO JESUS
# 19                                     REVELATION SONG
# 20                                   WHILE I'M WAITING
# 21                                         AWESOME GOD
# 22                                            REDEEMER
# 23                                   CITY ON OUR KNEES
# 24                               BLESS THE BROKEN ROAD
# 25                                        THIS IS HOME
# 26                                           ABOVE ALL
# 27                                      VOICE OF TRUTH
# 28                                           THANK YOU
# 29                                       HOLD MY HEART
# ..                                                 ...
# 527                             THIS OLD HEART OF MINE
# 528                                           SOUL MAN
# 529                                 PLEASE MR. POSTMAN
# 530                                   SWEET SOUL MUSIC
# 531                             ADVENTURES IN PARADISE
# 532                                   RAPPER'S DELIGHT
# 533                                       DUKE OF EARL
# 534                                          TELL MAMA
# 535                                         JIMMY MACK
# 537                                            SHOTGUN
# 538                          FA-FA-FA-FA-FA (SAD SONG)
# 539                                          GROOVE ME
# 540                    STANDING IN THE SHADOWS OF LOVE
# 541                                         TIGHTEN UP
# 542                                         LEAN ON ME
# 543                                          LOW RIDER
# 544                            I CAN'T GET NEXT TO YOU
# 545                                         LOVE TRAIN
# 546  HONEY LOVE - THE DRIFTERS FEATURING CLYDE MCPH...
# 547                                      MUSTANG SALLY
# 548                        YOU REALLY GOT A HOLD ON ME
# 542   Sometimes in our lives We all have pain We al...        R&B         271
# 543   INSTRUMENTAL All my friends know the low ride...        R&B          56
# 544   Hold it, everybody Hold it, hold it, listen  ...        R&B         284
# 545   The Ojays Miscellaneous Love Train LOVE TRAIN...        R&B         296
# 546   Love me, love me Love me, love me-lo Love me,...        R&B         334
# 547   Mustang Sally Guess you better slow your Must...        R&B         220
# 548   I dont like you, but I love you Seems that Im...        R&B         258
# 549   You got me doin it, you got me doin it You go...        R&B         247
# 550   I put a spell on you Because youre mine Stop ...        R&B          91
# 551   (Spoken:) I was born and raised down in Alaba...        R&B         459
# 552   Earth Wind And Fire All N All Serpentine Fire...        R&B         246
# 553   Ha I dont care ha, about your past I just wan...        R&B         139
# 554   Hoverin by my suitcase  Tryin to find a warm ...        R&B         255
# 555   I dont know why I love you like I do  After a...        R&B         236
# 556   C. C. Rider Elvis Presley  Well now see., C. ...        R&B         122
# 557   Cynthia get up and dance to the music!  Get o...        R&B         138
#
# [546 rows x 5 columns]

# %%
stats = df.groupby('Genre',as_index=False)['WordCounts'].mean()
stats = stats.rename(columns = {'WordCounts':'Mean'})
median = df.groupby('Genre')['WordCounts'].median()
minvalue = df.groupby('Genre')['WordCounts'].min()
maxvalue = df.groupby('Genre')['WordCounts'].max()
stats['Median'] = median.get_values()
stats['Min'] = minvalue.get_values()
stats['Max'] = maxvalue.get_values()

# %%
stats
# Out:
#        Genre        Mean  Median  Min   Max
# 0  Christian  218.095745   229.5    9   420
# 1    Country  195.068966   178.0   54   465
# 2        Pop  279.656250   256.5   10   963
# 3        R&B  253.209302   213.5   11  2961
# 4        Rap  649.406593   633.0   10  2892
# 5       Rock  229.434783   229.0    9   622

# %%
stats.plot(kind="bar",x="Genre")

# %% [markdown]
# # WORDCLOUDS

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction import text 
from wordcloud import WordCloud, STOPWORDS
genres = df['Genre'].unique()

for i in range(0,len(genres)):
    words = ' '.join(df.loc[df['Genre']==genres[i], 'Lyrics'])

    wordcloud = WordCloud( 
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=800,
                          height=400
                ).generate(words)
    print(genres[i])
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

words = ' '.join(df.loc[:, 'Lyrics'])

wordcloud = WordCloud( 
                      stopwords=STOPWORDS,
                      background_color='white',
                      width=800,
                      height=400
            ).generate(words)
print("ALL GENRES:")
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# Christian
# Country
# Rap
# Pop
# Rock
# R&B
# ALL GENRES:

# %%
from sklearn.preprocessing import LabelEncoder
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.4, random_state=0)
X_train = train['Lyrics'].values
y_train = train['Genre'].values
X_test = test['Lyrics'].values
y_test = test['Genre'].values

print('before: %s ...' %y_train[:5])

le = LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)

print('after: %s ...' %y_train[:5])
# Out:
# before: ['Pop' 'Pop' 'Christian' 'Country' 'Rock'] ...
# after: [2 2 0 1 5] ...

# %%
# Porter Stemmer

import nltk
import string
import re
from nltk.stem.snowball import EnglishStemmer
snowball = EnglishStemmer()
porter_stemmer = nltk.stem.porter.PorterStemmer()

def porter_tokenizer(text, stemmer=porter_stemmer):
    lower_txt = text.lower()
    tokens = nltk.wordpunct_tokenize(lower_txt)
    stems = [porter_stemmer.stem(t) for t in tokens]
    no_punct = [s for s in stems if re.match('^[a-zA-Z]+$', s) is not None]
    return no_punct

def snowball_tokenizer(text, stemmer=snowball):
    lower_txt = text.lower()
    tokens = nltk.wordpunct_tokenize(lower_txt)
    stems = [snowball.stem(t) for t in tokens]
    no_punct = [s for s in stems if re.match('^[a-zA-Z]+$', s) is not None]
    return no_punct

# %%
porter_tokenizer("One foot on the brake and one on the gas, hey...	")
# Out:
# ['one', 'foot', 'on', 'the', 'brake', 'and', 'one', 'on', 'the', 'ga', 'hey']

# %%
import nltk.corpus
# Commented out to prevent overwriting files:
#
stp = nltk.corpus.stopwords.words('english')
with open('./stopwords_eng.txt', 'w') as outfile:
    outfile.write('\n'.join(stp))
    

with open('./stopwords_eng.txt', 'r') as infile:
    stop_words = infile.read().splitlines()
print('stop words %s ...' %stop_words[:5])

#stop_words = []
# Out:
# stop words ['i', 'me', 'my', 'myself', 'we'] ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from mlxtend.preprocessing import DenseTransformer
import seaborn as sns

from sklearn import metrics

final_clf = Pipeline([
                ('vect', CountVectorizer(
                                        encoding='utf-8',
                                        decode_error='replace',
                                        strip_accents='unicode',
                                        analyzer='word',
                                        stop_words=stop_words,
                                        tokenizer=porter_tokenizer,
                                        binary=True,
                                        ngram_range=(1,1),
                                         )
                ),
                #('dense', DenseTransformer()),
                #('clf', MultinomialNB(alpha=0.1,fit_prior=False)),
                ('clf', BernoulliNB(alpha=0.001,fit_prior=False)),
                #('clf', DecisionTreeClassifier(criterion="gini",random_state=0,splitter="best",min_samples_split=2)),
                #('clf', RandomForestClassifier(criterion="entropy",random_state=0,oob_score=False,max_depth=40,n_estimators=500)),
                #('clf', KNeighborsClassifier(weights="distance",algorithm="auto",p=2,n_neighbors=6)),

               ])
final_clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=True, decode_error='replace',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=['i', 'me',...cabulary=None)), ('clf', BernoulliNB(alpha=0.001, binarize=0.0, class_prior=None, fit_prior=False))])

# %%
'''
from sklearn.model_selection import GridSearchCV
pipe_1 = Pipeline([
                ('vect', CountVectorizer(
                                        encoding='utf-8',
                                        decode_error='replace',
                                        strip_accents='unicode',
                                        analyzer='word',
                                        stop_words=stop_words,
                                        tokenizer=porter_tokenizer,
                                        binary=True,
                                        ngram_range=(1,1),
                                         )
                ),
                ('dense', DenseTransformer()),
                #('clf', MultinomialNB(alpha=0.1,fit_prior=False)),
                #('clf', BernoulliNB(alpha=0.001,fit_prior=False)),
                #('clf', DecisionTreeClassifier(criterion="gini",random_state=0,splitter="best",min_samples_split=2)),
                ('clf', RandomForestClassifier(max_depth=40)),
                #('clf', KNeighborsClassifier(n_neighbors=6)),
                #('clf', KMeans(n_clusters=6, random_state=0)),

               ])
parameters_1 = dict(
    clf__n_estimators=[50, 100, 200, 500],
    clf__max_features=['sqrt', 'log2', None],)

grid_search_1 = GridSearchCV(pipe_1, 
                             parameters_1, 
                             n_jobs=1, 
                             verbose=1,
                             scoring='accuracy',
                             cv=2)


print("Performing grid search...")
print("pipeline:", [name for name, _ in pipe_1.steps])
print("parameters:")
grid_search_1.fit(X_train, y_train)
print("Best score: %0.3f" % grid_search_1.best_score_)
print("Best parameters set:")
best_parameters_1 = grid_search_1.best_estimator_.get_params()
for param_name in sorted(parameters_1.keys()):
    print("\t%s: %r" % (param_name, best_parameters_1[param_name]))
    
final_clf = pipe_1
final_clf.fit(X_train, y_train)
'''
# Out:
# '\nfrom sklearn.model_selection import GridSearchCV\npipe_1 = Pipeline([\n                (\'vect\', CountVectorizer(\n                                        encoding=\'utf-8\',\n                                        decode_error=\'replace\',\n                                        strip_accents=\'unicode\',\n                                        analyzer=\'word\',\n                                        stop_words=stop_words,\n                                        tokenizer=porter_tokenizer,\n                                        binary=True,\n                                        ngram_range=(1,1),\n                                         )\n                ),\n                (\'dense\', DenseTransformer()),\n                #(\'clf\', MultinomialNB(alpha=0.1,fit_prior=False)),\n                #(\'clf\', BernoulliNB(alpha=0.001,fit_prior=False)),\n                #(\'clf\', DecisionTreeClassifier(criterion="gini",random_state=0,splitter="best",min_samples_split=2)),\n                (\'clf\', RandomForestClassifier(max_depth=40)),\n                #(\'clf\', KNeighborsClassifier(n_neighbors=6)),\n                #(\'clf\', KMeans(n_clusters=6, random_state=0)),\n\n               ])\nparameters_1 = dict(\n    clf__n_estimators=[50, 100, 200, 500],\n    clf__max_features=[\'sqrt\', \'log2\', None],)\n\ngrid_search_1 = GridSearchCV(pipe_1, \n                             parameters_1, \n                             n_jobs=1, \n                             verbose=1,\n                             scoring=\'accuracy\',\n                             cv=2)\n\n\nprint("Performing grid search...")\nprint("pipeline:", [name for name, _ in pipe_1.steps])\nprint("parameters:")\ngrid_search_1.fit(X_train, y_train)\nprint("Best score: %0.3f" % grid_search_1.best_score_)\nprint("Best parameters set:")\nbest_parameters_1 = grid_search_1.best_estimator_.get_params()\nfor param_name in sorted(parameters_1.keys()):\n    print("\t%s: %r" % (param_name, best_parameters_1[param_name]))\n    \nfinal_clf = pipe_1\nfinal_clf.fit(X_train, y_train)\n'

# %%
#import matplotlib as plt
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train, final_clf.predict(X_train)))
plt.figure(figsize=(5, 5))
cm = metrics.confusion_matrix(y_train, final_clf.predict(X_train))

np.set_printoptions(suppress=True)

hm = sns.heatmap(cm, 
            cbar=False,
            annot=True, 
            square=True,
            fmt='d',
            yticklabels=['christian','country','rock','pop','rap','r&b'],
            xticklabels=['christian','country','rock','pop','rap','r&b'],
            cmap='Blues'
            )
plt.title('Confusion matrix - Training dataset')
plt.ylabel('actual class')
plt.xlabel('predicted class')
plt.tight_layout()
plt.show()
# Out:
# 0.97247706422

# %%
y_test = le.transform(y_test)
print(accuracy_score(y_test, final_clf.predict(X_test)))
plt.figure(figsize=(5, 5))
cm = metrics.confusion_matrix(y_test, final_clf.predict(X_test))

np.set_printoptions(suppress=True)

hm = sns.heatmap(cm, 
            cbar=False,
            annot=True, 
            square=True,
            fmt='d',
            yticklabels=['christian','country','rock','pop','rap','r&b'],
            xticklabels=['christian','country','rock','pop','rap','r&b'],
            cmap='Blues'
            )
plt.title('Confusion matrix - Training dataset')
plt.ylabel('actual class')
plt.xlabel('predicted class')
plt.tight_layout()
plt.show()
# Out:
# 0.598173515982
