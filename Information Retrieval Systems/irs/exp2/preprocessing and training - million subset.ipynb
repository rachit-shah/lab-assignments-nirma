# %%
# %matplotlib inline
import matplotlib
import pandas as pd
import numpy as np


df = pd.read_csv("million_10000.csv", encoding = "ISO-8859-1")

# %%
df['genre'] = df.genre.str.replace("Hip Hop/Rap","Rap")

# %%
df
# Out:
#                        file                             artist  \
# 0     TRAAAAW128F429D538.h5                             Casual
# 1     TRAAAEF128F4273421.h5                           Adam Ant
# 2     TRAAAFD128F92F423A.h5                                Gob
# 3     TRAABJV128F1460C49.h5                      Lionel Richie
# 4     TRAABLR128F423B7E3.h5                         Blue Rodeo
# 5     TRAABVM128F92CA9DC.h5                              Tesla
# 6     TRAACER128F4290F96.h5          The Dillinger Escape Plan
# 7     TRAACFV128F935E50B.h5                       SUE THOMPSON
# 8     TRAACHN128F1489601.h5                     Five Bolt Main
# 9     TRAACNS128F14A2DF5.h5                        Willie Bobo
# 10    TRAACQT128F9331780.h5                        John Wesley
# 11    TRAACTB12903CAAF15.h5                   Billie Jo Spears
# 12    TRAADLN128F14832E9.h5                 The Rolling Stones
# 13    TRAADNA128F9331246.h5                 Stevie Ray Vaughan
# 14    TRAADQX128F422B4CF.h5  Casiotone For The Painfully Alone
# 15    TRAADYB128F92D7E73.h5                       Eliane Elias
# 16    TRAADYI128E078FB38.h5                          Lost Boyz
# 17    TRAAEAM128F934B199.h5                          The Germs
# 18    TRAAEEH128E0795DFE.h5                          Chris Rea
# 19    TRAAEUB12903CDD3EA.h5                      The Berzerker
# 20    TRAAEWG128F930B3A4.h5                      Kings Of Leon
# 21    TRAAFJW128F428A424.h5                               NOFX
# 22    TRAAFYL128E07856A7.h5                          Van Halen
# 23    TRAAGCZ128F93210FD.h5                    Black Eyed Peas
# 24    TRAAGEC128E079252C.h5                    Nine Inch Nails
# 25    TRAAGGE128F9325E2C.h5          Nick Cave & The Bad Seeds
# 26    TRAAGJV128F1464090.h5                        Lesley Gore
# 27    TRAAGPF12903CE027E.h5                       Slim Whitman
# 28    TRAAGPH128F4273C8D.h5                      Savage Garden
# 29    TRAAGPJ128F428CD1B.h5            Queens Of The Stone Age
# ...                     ...                                ...
# 1170  TRAJUAP128F423CB89.h5                          Nu Flavor
# 1171  TRAJUPI128F9324529.h5                      Reel Big Fish
# 1172  TRAJXED12903CC548C.h5                       Generation X
# 1173  TRAJYRB128F1491A59.h5                         Gary Moore
# 1174  TRAJZLM128F427CEB7.h5                               K-OS
# 1175  TRAJZWM128F4262BBD.h5                       Neil Diamond
# 1176  TRAKAGL128F148B3B7.h5                              Tesla
# 1177  TRAKBKO128F1481CFA.h5                        White Heart
# 1178  TRAKBON128F9311039.h5                 The Rolling Stones
# 1179  TRAKCFG128F149D9B7.h5                         Tracy Byrd
# 1180  TRAKDCQ128F42A247A.h5                       Kool Moe Dee
# 1181  TRAKDMK128F92F9AFC.h5                 The Tragically Hip
# 1182  TRAKGDA128F423CBC8.h5                    Tony Matterhorn
# 1183  TRAKGDZ12903CE4867.h5                  Story Of The Year
# 1184  TRAKHAU128F42927B4.h5                       Busta Rhymes
# 1185  TRAKHXX128E07877EB.h5              Red Hot Chili Peppers
# 1186  TRAKJNX128F92CF428.h5                             Fergie
# 1187  TRAKJTB128F148C560.h5                       Erick Sermon
# 1188  TRAKKTE128F934B0D9.h5                       THE CHIFFONS
# 1189  TRAKLHO128F42BA554.h5                 The Rolling Stones
# 1190  TRAKNDG128F428A228.h5                       Connie Smith
# 1191  TRAKORW128F1484DF0.h5                      Janet Jackson
# 1192  TRAKOWP128F42988F8.h5            Daryl Hall & John Oates
# 1193  TRAKPJC128F4258613.h5               Juliette & The Licks
# 1194  TRAKPND128F42389EA.h5                       Phil Collins
# 1195  TRAKQEA128F1495E21.h5                             Prince
# 1196  TRAKQLN128F932AC25.h5                               Cavo
# 1197  TRAKQXJ128F147A028.h5                                AFI
# 1198  TRAKRQW128F427D6E3.h5                          Vitamin C
# 1199  TRAKSRQ128F4269AE8.h5                     Richard Burton
#
#                                               title  \
# 0                                  I Didn't Mean To
# 1                                   Something Girls
# 2                                    Face the Ashes
# 3                           Tonight Will Be Alright
# 4                                          Floating
# 5                                 Caught In A Dream
# 6                   Setting Fire to Sleeping Giants
# 7                    James (Hold The Ladder Steady)
# 8                             Made Like This (Live)
# 9                                    Spanish Grease
# 10                                The Emperor Falls
# 11                       It Makes No Difference Now
# 12                    Angie (1993 Digital Remaster)
# 13                                        Crossfire
# 14                              Nashville Parthenon
# 15                               The More I See You
# 16                             Certain Things We Do
# 17                                          Forming
# 18                       Driving Home For Christmas
# 19                                    Deform (live)
# 20                                     Wicker Chair
# 21                                Stickin In My Eye
# 22                Panama (Remastered Album Version)
# 23                             Let's Get It Started
# 24                                            Metal
# 25            She Fell Away (2009 Digital Remaster)
# 26                                    It's My Party
# 27                                 Indian Love Call
# 28                            You Can Still Be Free
# 29                                     I Never Came
# ...                                             ...
# 1170                     Sprung (Cibola Mix W/ Rap)
# 1171                        Veronica Sawyer (Album)
# 1172  Dancing With Myself (BBC In Concert 01/01/81)
# 1173                             Nothing's The Same
# 1174                                   B-Boy Stance
# 1175                                 Song Sung Blue
# 1176                                 Gettin' Better
# 1177                              Sing Your Freedom
# 1178                              Around And Around
# 1179                                     Walkin' In
# 1180                                   I Go To Work
# 1181                                    Country Day
# 1182                                     Dutty Wine
# 1183                                  Won Threw Ate
# 1184                                       Taste It
# 1185                    Emit Remmus (Album Version)
# 1186                                  London Bridge
# 1187                                       Safe Sex
# 1188                                   One Fine Day
# 1189                                      Rocks Off
# 1190                               If I Talk To Him
# 1191                                   Hold On Baby
# 1192                  Everything Your Heart Desires
# 1193                             Shelter Your Needs
# 1194             You Can't Hurry Love  (LP Version)
# 1195                           Escape ( LP Version)
# 1196                     Over Again (Album Version)
# 1197                                 Summer Shudder
# 1198                Girls Against Boys (LP Version)
# 1199                                        Camelot
#
#                                                  lyrics       genre
# 0     Verse One:\r\n\r\nAlright I might\r\nHave had ...         Rap
# 1     Adam Ant/Marco Pirroni\r\nEvery girl is a some...        Rock
# 2     I've just erased it's been a while, I've got a...        Rock
# 3     Little darling \r\nWhere you've been so long \...         R&B
# 4     Lead Vocal by Greg\r\n\r\nWell, these late nig...        Rock
# 5     If you can imagine this\r\nThe whole world sha...        Rock
# 6     First off let me say you look so tired...\r\nR...        Rock
# 7     James, James hold the ladder steady\r\nJames, ...         Pop
# 8     Conclusions, illusions, of mainstream intrusio...        Rock
# 9     Ain't no love\r\nAin't no love\r\nAin't no lov...        Jazz
# 10    Brick by brick\r\nstone by stone\r\ndismantle ...        Rock
# 11    Makes no difference now what kind of life fate...     Country
# 12    Angie, Angie\r\nWhen will those clouds all dis...        Rock
# 13    Day by day, night after night,\r\nBlinded by t...       Blues
# 14    If you ever make it back to Nashville\r\nRemem...        Jazz
# 15    The more I see you the more I want you\r\nSome...        Jazz
# 16    (Chorus: Mr. Cheeks)\r\nAll my ladies and mens...         Rap
# 17    Rip them down\r\nHold me up\r\nTell them that\...        Rock
# 18    I'm driving home for Christmas\r\nI can't wait...        Rock
# 19    Degradation, i don't want your, \r\nrhinoplast...  Electronic
# 20    In your little white wicker chair \r\nUnsuspic...        Rock
# 21    When I look 'round, I only see outta one eye\r...        Rock
# 22    Oh yeah!\r\nUh-huh!\r\n\r\nJump back, what's t...        Rock
# 23    Let's get it started, in here...\r\n\r\nAnd th...         Rap
# 24    We're in the building where they make us grow\...        Rock
# 25    Once she lay open like a road\r\nCarbed apart ...        Rock
# 26    It's my party and I'll cry if I want to\r\nCry...         Pop
# 27    Oo-Oo-Oo-Oo, Oo-Oo-Oo-Oo\r\nWhen I'm calling y...     Country
# 28    Cool breeze and autumn leaves\r\nSlow motion d...        Rock
# 29    When you say it's dead and gone\r\nYes, I know...        Rock
# ...                                                 ...         ...
# 1170  You used to be this little girl around the way...  Electronic
# 1171  Originally by Edna's Goldfish\r\nREEL BIG FISH...         Ska
# 1172  On the floors of Tokyo\r\nOr down in London to...        Rock
# 1173  Another town, another place\r\nThe lonely stre...        Rock
# 1174  Ya. its so hard to remain authentic\r\nEveryth...         Rap
# 1175  Song sung blue\r\nEverybody knows one\r\nSong ...        Rock
# 1176  Fallin' rain\r\nOutside my window\r\nBut I'll ...        Rock
# 1177  Let's come out and say the truth\r\nLiving can...   Christian
# 1178  I said the joint was rocking \r\nGoin' round a...        Rock
# 1179  I've done my share of walkin' out\r\nI've kept...     Country
# 1180  I go to work like a doctor\r\nWhen I rock the ...         Rap
# 1181  Country day\r\nA day in the unknown\r\nA gentl...        Rock
# 1182  Intro \r\nAttitude Gal \r\nOne of dem two of d...         Ska
# 1183  Blood still pours down onto the page\r\nPride ...        Rock
# 1184  (Repeat 5x (Taste it, taste it, taste it))\r\n...         Rap
# 1185  The California animal is a bear\r\nAngeleno bu...        Rock
# 1186  Oh shit, oh shit, oh shit\r\nOh shit, oh shit,...         Pop
# 1187  sex\r\nhave some sex\r\nsafe sex\r\nword 'em u...         Rap
# 1188  Shoobie doobie doobie doobie doo wop bop (x2)\...         R&B
# 1189  I hear you talking when I'm on the street\r\nY...        Rock
# 1190  If I talk to him I take him back again so if h...     Country
# 1191  (sounds of the ocean)\r\n\r\nHold on, baby, le...         R&B
# 1192  You say you can't stand to be tied so close to...         R&B
# 1193  Put it in my hand\r\nTell me how much pressure...        Rock
# 1194  I need love, love to ease my mind\r\nI need to...        Rock
# 1195  {B-side of Glam Slam}\r\nSnare drum pounds on ...        Rock
# 1196  Well I will rise\r\nThe morning comes\r\nNothi...        Rock
# 1197  Listen when I say, when I say it's real\r\nRea...        Rock
# 1198  Imagine a world where the girls, girls rule th...         Pop
# 1199  Each evening, from December to December\r\nBef...        Jazz
#
# [1200 rows x 5 columns]

# %%
df= df.drop_duplicates(subset="title")
df['genre'].value_counts()
# Out:
# Rock          631
# Rap           128
# Pop            97
# Country        92
# R&B            60
# Christian      51
# Electronic     48
# Blues          27
# Ska            21
# Jazz           17
# Soul           10
# Dance           2
# Name: genre, dtype: int64

# %%
wordcounts = df.lyrics.str.split().apply(len)
df['WordCounts'] = wordcounts
df
# Out:
# c:\users\hp\anaconda3\envs\tensor\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        file                             artist  \
# 0     TRAAAAW128F429D538.h5                             Casual
# 1     TRAAAEF128F4273421.h5                           Adam Ant
# 2     TRAAAFD128F92F423A.h5                                Gob
# 3     TRAABJV128F1460C49.h5                      Lionel Richie
# 4     TRAABLR128F423B7E3.h5                         Blue Rodeo
# 5     TRAABVM128F92CA9DC.h5                              Tesla
# 6     TRAACER128F4290F96.h5          The Dillinger Escape Plan
# 7     TRAACFV128F935E50B.h5                       SUE THOMPSON
# 8     TRAACHN128F1489601.h5                     Five Bolt Main
# 9     TRAACNS128F14A2DF5.h5                        Willie Bobo
# 10    TRAACQT128F9331780.h5                        John Wesley
# 11    TRAACTB12903CAAF15.h5                   Billie Jo Spears
# 12    TRAADLN128F14832E9.h5                 The Rolling Stones
# 13    TRAADNA128F9331246.h5                 Stevie Ray Vaughan
# 14    TRAADQX128F422B4CF.h5  Casiotone For The Painfully Alone
# 15    TRAADYB128F92D7E73.h5                       Eliane Elias
# 16    TRAADYI128E078FB38.h5                          Lost Boyz
# 17    TRAAEAM128F934B199.h5                          The Germs
# 18    TRAAEEH128E0795DFE.h5                          Chris Rea
# 19    TRAAEUB12903CDD3EA.h5                      The Berzerker
# 20    TRAAEWG128F930B3A4.h5                      Kings Of Leon
# 21    TRAAFJW128F428A424.h5                               NOFX
# 22    TRAAFYL128E07856A7.h5                          Van Halen
# 23    TRAAGCZ128F93210FD.h5                    Black Eyed Peas
# 24    TRAAGEC128E079252C.h5                    Nine Inch Nails
# 25    TRAAGGE128F9325E2C.h5          Nick Cave & The Bad Seeds
# 26    TRAAGJV128F1464090.h5                        Lesley Gore
# 27    TRAAGPF12903CE027E.h5                       Slim Whitman
# 28    TRAAGPH128F4273C8D.h5                      Savage Garden
# 29    TRAAGPJ128F428CD1B.h5            Queens Of The Stone Age
# ...                     ...                                ...
# 1169  TRAJRIT128F92F4352.h5                              Usher
# 1170  TRAJUAP128F423CB89.h5                          Nu Flavor
# 1171  TRAJUPI128F9324529.h5                      Reel Big Fish
# 1172  TRAJXED12903CC548C.h5                       Generation X
# 1173  TRAJYRB128F1491A59.h5                         Gary Moore
# 1174  TRAJZLM128F427CEB7.h5                               K-OS
# 1176  TRAKAGL128F148B3B7.h5                              Tesla
# 1177  TRAKBKO128F1481CFA.h5                        White Heart
# 1178  TRAKBON128F9311039.h5                 The Rolling Stones
# 1179  TRAKCFG128F149D9B7.h5                         Tracy Byrd
# 1180  TRAKDCQ128F42A247A.h5                       Kool Moe Dee
# 1181  TRAKDMK128F92F9AFC.h5                 The Tragically Hip
# 1182  TRAKGDA128F423CBC8.h5                    Tony Matterhorn
# 1183  TRAKGDZ12903CE4867.h5                  Story Of The Year
# 1184  TRAKHAU128F42927B4.h5                       Busta Rhymes
# 1185  TRAKHXX128E07877EB.h5              Red Hot Chili Peppers
# 1186  TRAKJNX128F92CF428.h5                             Fergie
# 1187  TRAKJTB128F148C560.h5                       Erick Sermon
# 1188  TRAKKTE128F934B0D9.h5                       THE CHIFFONS
# 1189  TRAKLHO128F42BA554.h5                 The Rolling Stones
# 1190  TRAKNDG128F428A228.h5                       Connie Smith
# 1191  TRAKORW128F1484DF0.h5                      Janet Jackson
# 1192  TRAKOWP128F42988F8.h5            Daryl Hall & John Oates
# 1193  TRAKPJC128F4258613.h5               Juliette & The Licks
# 1194  TRAKPND128F42389EA.h5                       Phil Collins
# 1195  TRAKQEA128F1495E21.h5                             Prince
# 1196  TRAKQLN128F932AC25.h5                               Cavo
# 1197  TRAKQXJ128F147A028.h5                                AFI
# 1198  TRAKRQW128F427D6E3.h5                          Vitamin C
# 1199  TRAKSRQ128F4269AE8.h5                     Richard Burton
#
#                                               title  \
# 0                                  I Didn't Mean To
# 1                                   Something Girls
# 2                                    Face the Ashes
# 3                           Tonight Will Be Alright
# 4                                          Floating
# 5                                 Caught In A Dream
# 6                   Setting Fire to Sleeping Giants
# 7                    James (Hold The Ladder Steady)
# 8                             Made Like This (Live)
# 9                                    Spanish Grease
# 10                                The Emperor Falls
# 11                       It Makes No Difference Now
# 12                    Angie (1993 Digital Remaster)
# 13                                        Crossfire
# 14                              Nashville Parthenon
# 15                               The More I See You
# 16                             Certain Things We Do
# 17                                          Forming
# 18                       Driving Home For Christmas
# 19                                    Deform (live)
# 20                                     Wicker Chair
# 21                                Stickin In My Eye
# 22                Panama (Remastered Album Version)
# 23                             Let's Get It Started
# 24                                            Metal
# 25            She Fell Away (2009 Digital Remaster)
# 26                                    It's My Party
# 27                                 Indian Love Call
# 28                            You Can Still Be Free
# 29                                     I Never Came
# ...                                             ...
# 1169                                 Trading Places
# 1170                     Sprung (Cibola Mix W/ Rap)
# 1171                        Veronica Sawyer (Album)
# 1172  Dancing With Myself (BBC In Concert 01/01/81)
# 1173                             Nothing's The Same
# 1174                                   B-Boy Stance
# 1176                                 Gettin' Better
# 1177                              Sing Your Freedom
# 1178                              Around And Around
# 1179                                     Walkin' In
# 1180                                   I Go To Work
# 1181                                    Country Day
# 1182                                     Dutty Wine
# 1183                                  Won Threw Ate
# 1184                                       Taste It
# 1185                    Emit Remmus (Album Version)
# 1186                                  London Bridge
# 1187                                       Safe Sex
# 1188                                   One Fine Day
# 1189                                      Rocks Off
# 1190                               If I Talk To Him
# 1191                                   Hold On Baby
# 1192                  Everything Your Heart Desires
# 1193                             Shelter Your Needs
# 1194             You Can't Hurry Love  (LP Version)
# 1195                           Escape ( LP Version)
# 1196                     Over Again (Album Version)
# 1197                                 Summer Shudder
# 1198                Girls Against Boys (LP Version)
# 1199                                        Camelot
#
#                                                  lyrics       genre  \
# 0     Verse One:\r\n\r\nAlright I might\r\nHave had ...         Rap
# 1     Adam Ant/Marco Pirroni\r\nEvery girl is a some...        Rock
# 2     I've just erased it's been a while, I've got a...        Rock
# 3     Little darling \r\nWhere you've been so long \...         R&B
# 4     Lead Vocal by Greg\r\n\r\nWell, these late nig...        Rock
# 5     If you can imagine this\r\nThe whole world sha...        Rock
# 6     First off let me say you look so tired...\r\nR...        Rock
# 7     James, James hold the ladder steady\r\nJames, ...         Pop
# 8     Conclusions, illusions, of mainstream intrusio...        Rock
# 9     Ain't no love\r\nAin't no love\r\nAin't no lov...        Jazz
# 10    Brick by brick\r\nstone by stone\r\ndismantle ...        Rock
# 11    Makes no difference now what kind of life fate...     Country
# 12    Angie, Angie\r\nWhen will those clouds all dis...        Rock
# 13    Day by day, night after night,\r\nBlinded by t...       Blues
# 14    If you ever make it back to Nashville\r\nRemem...        Jazz
# 15    The more I see you the more I want you\r\nSome...        Jazz
# 16    (Chorus: Mr. Cheeks)\r\nAll my ladies and mens...         Rap
# 17    Rip them down\r\nHold me up\r\nTell them that\...        Rock
# 18    I'm driving home for Christmas\r\nI can't wait...        Rock
# 19    Degradation, i don't want your, \r\nrhinoplast...  Electronic
# 20    In your little white wicker chair \r\nUnsuspic...        Rock
# 21    When I look 'round, I only see outta one eye\r...        Rock
# 22    Oh yeah!\r\nUh-huh!\r\n\r\nJump back, what's t...        Rock
# 23    Let's get it started, in here...\r\n\r\nAnd th...         Rap
# 24    We're in the building where they make us grow\...        Rock
# 25    Once she lay open like a road\r\nCarbed apart ...        Rock
# 26    It's my party and I'll cry if I want to\r\nCry...         Pop
# 27    Oo-Oo-Oo-Oo, Oo-Oo-Oo-Oo\r\nWhen I'm calling y...     Country
# 28    Cool breeze and autumn leaves\r\nSlow motion d...        Rock
# 29    When you say it's dead and gone\r\nYes, I know...        Rock
# ...                                                 ...         ...
# 1169  I know what you used to \r\nWe gon' do somethi...         Rap
# 1170  You used to be this little girl around the way...  Electronic
# 1171  Originally by Edna's Goldfish\r\nREEL BIG FISH...         Ska
# 1172  On the floors of Tokyo\r\nOr down in London to...        Rock
# 1173  Another town, another place\r\nThe lonely stre...        Rock
# 1174  Ya. its so hard to remain authentic\r\nEveryth...         Rap
# 1176  Fallin' rain\r\nOutside my window\r\nBut I'll ...        Rock
# 1177  Let's come out and say the truth\r\nLiving can...   Christian
# 1178  I said the joint was rocking \r\nGoin' round a...        Rock
# 1179  I've done my share of walkin' out\r\nI've kept...     Country
# 1180  I go to work like a doctor\r\nWhen I rock the ...         Rap
# 1181  Country day\r\nA day in the unknown\r\nA gentl...        Rock
# 1182  Intro \r\nAttitude Gal \r\nOne of dem two of d...         Ska
# 1183  Blood still pours down onto the page\r\nPride ...        Rock
# 1184  (Repeat 5x (Taste it, taste it, taste it))\r\n...         Rap
# 1185  The California animal is a bear\r\nAngeleno bu...        Rock
# 1186  Oh shit, oh shit, oh shit\r\nOh shit, oh shit,...         Pop
# 1187  sex\r\nhave some sex\r\nsafe sex\r\nword 'em u...         Rap
# 1188  Shoobie doobie doobie doobie doo wop bop (x2)\...         R&B
# 1189  I hear you talking when I'm on the street\r\nY...        Rock
# 1190  If I talk to him I take him back again so if h...     Country
# 1191  (sounds of the ocean)\r\n\r\nHold on, baby, le...         R&B
# 1192  You say you can't stand to be tied so close to...         R&B
# 1193  Put it in my hand\r\nTell me how much pressure...        Rock
# 1194  I need love, love to ease my mind\r\nI need to...        Rock
# 1195  {B-side of Glam Slam}\r\nSnare drum pounds on ...        Rock
# 1196  Well I will rise\r\nThe morning comes\r\nNothi...        Rock
# 1197  Listen when I say, when I say it's real\r\nRea...        Rock
# 1198  Imagine a world where the girls, girls rule th...         Pop
# 1199  Each evening, from December to December\r\nBef...        Jazz
#
#       WordCounts
# 0            458
# 1            137
# 2            123
# 3            183
# 4            219
# 5            311
# 6            232
# 7            236
# 8            158
# 9            242
# 10           205
# 11           167
# 12           186
# 13           155
# 14           134
# 15           227
# 16           702
# 17           186
# 18           373
# 19           206
# 20           190
# 21           120
# 22           168
# 23           599
# 24           131
# 25           140
# 26           230
# 27            93
# 28           172
# 29           172
# ...          ...
# 1169         535
# 1170         277
# 1171         373
# 1172         360
# 1173         133
# 1174         387
# 1176         210
# 1177         205
# 1178         201
# 1179         202
# 1180         702
# 1181         276
# 1182         681
# 1183         218
# 1184         669
# 1185         260
# 1186         484
# 1187         373
# 1188         178
# 1189         258
# 1190         160
# 1191          12
# 1192         355
# 1193         313
# 1194         358
# 1195         273
# 1196         278
# 1197         195
# 1198         283
# 1199         107
#
# [1184 rows x 6 columns]

# %%
stats = df.groupby('genre',as_index=False)['WordCounts'].mean()
stats = stats.rename(columns = {'WordCounts':'Mean'})
median = df.groupby('genre')['WordCounts'].median()
minvalue = df.groupby('genre')['WordCounts'].min()
maxvalue = df.groupby('genre')['WordCounts'].max()
stats['Median'] = median.get_values()
stats['Min'] = minvalue.get_values()
stats['Max'] = maxvalue.get_values()

# %%
stats
# Out:
#          genre        Mean  Median  Min   Max
# 0        Blues  195.185185   183.0  101   407
# 1    Christian  215.411765   207.0   88   651
# 2      Country  178.282609   167.0   63   313
# 3        Dance  242.500000   242.5  192   293
# 4   Electronic  208.562500   183.0   48   438
# 5         Jazz  155.705882   155.0   51   248
# 6          Pop  252.020619   236.0   33   620
# 7          R&B  308.250000   273.5   12   649
# 8          Rap  496.796875   505.0   52  1049
# 9         Rock  203.115689   193.0    1   733
# 10         Ska  269.285714   215.0  157   681
# 11        Soul  284.000000   226.0  154   511

# %%
stats.plot(kind="bar",x="genre")

# %% [markdown]
# # WORDCLOUDS

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction import text 
from wordcloud import WordCloud, STOPWORDS
genres = df['genre'].unique()

for i in range(0,len(genres)):
    words = ' '.join(df.loc[df['genre']==genres[i], 'lyrics'])

    wordcloud = WordCloud( 
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=800,
                          height=400
                ).generate(words)
    print(genres[i])
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

words = ' '.join(df.loc[:, 'lyrics'])

wordcloud = WordCloud( 
                      stopwords=STOPWORDS,
                      background_color='white',
                      width=800,
                      height=400
            ).generate(words)
print("ALL GENRES:")
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# Rap
# Rock
# R&B
# Pop
# Jazz
# Country
# Blues
# Electronic
# Soul
# Ska
# Christian
# Dance
# ALL GENRES:

# %%
from sklearn.preprocessing import LabelEncoder
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.4, random_state=0)
X_train = train['lyrics'].values
y_train = train['genre'].values
X_test = test['lyrics'].values
y_test = test['genre'].values

print('before: %s ...' %y_train[:5])

le = LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)

print('after: %s ...' %y_train)
# Out:
# before: ['Rock' 'Pop' 'Country' 'Rock' 'Rock'] ...
# after: [ 8  5  2  8  8  6  6  7  7  4  8  8  8  8  8  7  8  8  1  1  8  2  8  2  8
#   8  8  8  8  8  2  5  8  5  1  8  5  8  7  8  3  3  8  1  7  5  8  7  7  8
#   8  1  8  8  8  8  8  8  8  8  1  8  9  8  8  7  1  7  7  8  7  7  8  1  6
#   8  3  8  8  6  5  8  8  8  3  7  8  8  1  6  1  8  6  6  8  2  8  2  7  7
#   8  8  8  8  2  7  7  8  5  8  5 10  8  5  5  2  3  8 10  2  8  5  1  8  8
#   8  8  7  8  8  8  8  2  7  8  1  1  8  8  9  2  8  3  8  1  4  6  3  8  8
#   2  8  5  8  8  0  8  8  8  8  8  8  8  8  8  6  5  3  8  7  8  8  8  8  5
#   7  8  8  8  8  2  6  8  1  8  8  8  8  8  3  8  8  8  8  8  5  8  7  7  8
#   1  0  8  8  8  2  8  8  7  8  8  8  7  5  8  8  8  8  2  8  7  8  9  6  9
#   5  5  8  3  8  8  8  8  8  8  3  8  6  8  2  8  7  9  8  0  8  6  8  0  0
#   8  5  8  8  1  4  2  6  8  8  7  2  8  8  8  4  8  5  8  8  3  8  7  8  8
#   8  5  6  7  8  8  1  8  8  1  4  5  8  7  8  9  3  7  8  5  5  5  8  8  2
#   8  8  7  6  8  8  8  9  6 10  8  8  8  8  8  8  8  8  1  8  8  6  7  8  8
#   8  2  6  5  7  2  0  8  7  8  8  8  8  2  8  8  5  6  3  8  8  2  9  8  1
#   2  8  0  7  7  5  6  8  8  8  2  8  7  5  8  3  8  8  8  8  5  2  6  8  3
#   7  7  8  8  8  8  8  8  8  2  2  8  2  8  9  7  8  2  0  7  9  5  8  7  7
#   5  9  8  8  8  2 10  8  8  8  7  8  7  2  2  8  5  1  8  7  8  5  1  1  8
#   8  9  7  8  8  8  8  3  3  6  6  5  8  8  8  2  8  8  2  0  8  8  8  8  8
#   6  2  2  6  8  8  8  8  1  8  7  8  7  8  5  8  3  8  1  8  7  7  8  8  9
#   8  6  8  8  8  8  5  8  8  6  3  8  8  2  1  8  8  8  3  8  8  7  8  8  8
#   8  8  8  8  7  8  8  5  8  6  0  8  8  7  8  6  8  8  5  5  6  8  8  7  6
#   8 10  7  8  5  8  7  3  8  5  8  8  8  8  8  8  2  7  8  8  8  8  5  8  7
#   8  8  8  7  5  8  8  1  5  5  8  8  8  9  8  8  5  8  8  8  0  8  8  8  7
#   8  8  8  7  4  8  3  8  3  8  8  7  8  8  7  3  2  5  8  2  5  7  7  2  8
#   2  2  8  8  8  8  8  3  2  6  8  7  8  6  2  8  5  8  8  7  5  7  6  7  8
#   1  3  8  8  7  8  2  8  5  8  7  8  2  8  8  3  7  7  8  8  8  0  5  7  8
#   8  7  8  8  9  8  8  2  8  5  8  7  0  8  8  8  8  5  6  8  8  3  2  8  5
#   8  8  8  6  8  5  8  8  1  8  2  1  5  7  0  8  8  5  8  8  8  8  5  8  1
#   3  6  7  8  8  6  7  7  8  8] ...

# %%
# Porter Stemmer

import nltk
import string
import re
from nltk.stem.snowball import EnglishStemmer
snowball = EnglishStemmer()
porter_stemmer = nltk.stem.porter.PorterStemmer()

def porter_tokenizer(text, stemmer=porter_stemmer):
    lower_txt = text.lower()
    tokens = nltk.wordpunct_tokenize(lower_txt)
    stems = [porter_stemmer.stem(t) for t in tokens]
    no_punct = [s for s in stems if re.match('^[a-zA-Z]+$', s) is not None]
    return no_punct

def snowball_tokenizer(text, stemmer=snowball):
    lower_txt = text.lower()
    tokens = nltk.wordpunct_tokenize(lower_txt)
    stems = [snowball.stem(t) for t in tokens]
    no_punct = [s for s in stems if re.match('^[a-zA-Z]+$', s) is not None]
    return no_punct

# %%
import nltk.corpus
# Commented out to prevent overwriting files:
#
stp = nltk.corpus.stopwords.words('english')
with open('./stopwords_eng.txt', 'w') as outfile:
    outfile.write('\n'.join(stp))
    

with open('./stopwords_eng.txt', 'r') as infile:
    stop_words = infile.read().splitlines()
print('stop words %s ...' %stop_words[:5])

#stop_words = []
# Out:
# stop words ['i', 'me', 'my', 'myself', 'we'] ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from mlxtend.preprocessing import DenseTransformer
import seaborn as sns

from sklearn import metrics

final_clf = Pipeline([
                ('vect', CountVectorizer(
                                        encoding='utf-8',
                                        decode_error='replace',
                                        strip_accents='unicode',
                                        analyzer='word',
                                        stop_words=stop_words,
                                        tokenizer=porter_tokenizer,
                                        binary=True,
                                        ngram_range=(1,1),
                                         )
                ),
                #('dense', DenseTransformer()),
                #('clf', MultinomialNB(alpha=0.1,fit_prior=False)),
                ('clf', BernoulliNB(alpha=0.001,fit_prior=False)),
                #('clf', DecisionTreeClassifier(criterion="gini",random_state=0,splitter="best",min_samples_split=2)),
                #('clf', RandomForestClassifier(criterion="entropy",random_state=0,oob_score=False,max_depth=40,n_estimators=500)),
                #('clf', KNeighborsClassifier(weights="distance",algorithm="auto",p=2,n_neighbors=6)),

               ])
final_clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=True, decode_error='replace',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=['i', 'me',...cabulary=None)), ('clf', BernoulliNB(alpha=0.001, binarize=0.0, class_prior=None, fit_prior=False))])

# %%
'''
from sklearn.model_selection import GridSearchCV
pipe_1 = Pipeline([
                ('vect', CountVectorizer(
                                        encoding='utf-8',
                                        decode_error='replace',
                                        strip_accents='unicode',
                                        analyzer='word',
                                        stop_words=stop_words,
                                        tokenizer=porter_tokenizer,
                                        binary=True,
                                        ngram_range=(1,1),
                                         )
                ),
                ('dense', DenseTransformer()),
                #('clf', MultinomialNB(alpha=0.1,fit_prior=False)),
                #('clf', BernoulliNB(alpha=0.001,fit_prior=False)),
                #('clf', DecisionTreeClassifier(criterion="gini",random_state=0,splitter="best",min_samples_split=2)),
                ('clf', RandomForestClassifier(max_depth=40)),
                #('clf', KNeighborsClassifier(n_neighbors=6)),
                #('clf', KMeans(n_clusters=6, random_state=0)),

               ])
parameters_1 = dict(
    clf__n_estimators=[50, 100, 200, 500],
    clf__max_features=['sqrt', 'log2', None],)

grid_search_1 = GridSearchCV(pipe_1, 
                             parameters_1, 
                             n_jobs=1, 
                             verbose=1,
                             scoring='accuracy',
                             cv=2)


print("Performing grid search...")
print("pipeline:", [name for name, _ in pipe_1.steps])
print("parameters:")
grid_search_1.fit(X_train, y_train)
print("Best score: %0.3f" % grid_search_1.best_score_)
print("Best parameters set:")
best_parameters_1 = grid_search_1.best_estimator_.get_params()
for param_name in sorted(parameters_1.keys()):
    print("\t%s: %r" % (param_name, best_parameters_1[param_name]))
    
final_clf = pipe_1
final_clf.fit(X_train, y_train)
'''
# Out:
# '\nfrom sklearn.model_selection import GridSearchCV\npipe_1 = Pipeline([\n                (\'vect\', CountVectorizer(\n                                        encoding=\'utf-8\',\n                                        decode_error=\'replace\',\n                                        strip_accents=\'unicode\',\n                                        analyzer=\'word\',\n                                        stop_words=stop_words,\n                                        tokenizer=porter_tokenizer,\n                                        binary=True,\n                                        ngram_range=(1,1),\n                                         )\n                ),\n                (\'dense\', DenseTransformer()),\n                #(\'clf\', MultinomialNB(alpha=0.1,fit_prior=False)),\n                #(\'clf\', BernoulliNB(alpha=0.001,fit_prior=False)),\n                #(\'clf\', DecisionTreeClassifier(criterion="gini",random_state=0,splitter="best",min_samples_split=2)),\n                (\'clf\', RandomForestClassifier(max_depth=40)),\n                #(\'clf\', KNeighborsClassifier(n_neighbors=6)),\n                #(\'clf\', KMeans(n_clusters=6, random_state=0)),\n\n               ])\nparameters_1 = dict(\n    clf__n_estimators=[50, 100, 200, 500],\n    clf__max_features=[\'sqrt\', \'log2\', None],)\n\ngrid_search_1 = GridSearchCV(pipe_1, \n                             parameters_1, \n                             n_jobs=1, \n                             verbose=1,\n                             scoring=\'accuracy\',\n                             cv=2)\n\n\nprint("Performing grid search...")\nprint("pipeline:", [name for name, _ in pipe_1.steps])\nprint("parameters:")\ngrid_search_1.fit(X_train, y_train)\nprint("Best score: %0.3f" % grid_search_1.best_score_)\nprint("Best parameters set:")\nbest_parameters_1 = grid_search_1.best_estimator_.get_params()\nfor param_name in sorted(parameters_1.keys()):\n    print("\t%s: %r" % (param_name, best_parameters_1[param_name]))\n    \nfinal_clf = pipe_1\nfinal_clf.fit(X_train, y_train)\n'

# %%
labels = np.arange(len(genres)-1)
labels = le.inverse_transform(labels)

# %%
#import matplotlib as plt
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
print(accuracy_score(y_train, final_clf.predict(X_train)))
plt.figure(figsize=(5, 5))
cm = metrics.confusion_matrix(y_train, final_clf.predict(X_train))

np.set_printoptions(suppress=True)

hm = sns.heatmap(cm, 
            cbar=False,
            annot=True, 
            square=True,
            fmt='d',
            yticklabels=labels,
            xticklabels=labels,
            cmap='Blues'
            )
plt.title('Confusion matrix - Training dataset')
plt.ylabel('actual class')
plt.xlabel('predicted class')
plt.tight_layout()
plt.show()
# Out:
# 0.974647887324

# %%
import bisect
test['genre'] = test['genre'].map(lambda s: 'other' if s not in le.classes_ else s)
le_classes = le.classes_.tolist()
bisect.insort_left(le_classes, 'other')
le.classes_ = le_classes
y_test = le.transform(y_test)
print(accuracy_score(y_test, final_clf.predict(X_test)))
plt.figure(figsize=(5, 5))
cm = metrics.confusion_matrix(y_test, final_clf.predict(X_test))

np.set_printoptions(suppress=True)

hm = sns.heatmap(cm, 
            cbar=False,
            annot=True, 
            square=True,
            fmt='d',
            yticklabels=labels,
            xticklabels=labels,
            cmap='Blues'
            )
plt.title('Confusion matrix - Training dataset')
plt.ylabel('actual class')
plt.xlabel('predicted class')
plt.tight_layout()
plt.show()
# Out:
# c:\users\hp\anaconda3\envs\tensor\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.584388185654
